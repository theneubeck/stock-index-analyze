# %%
from pathlib import Path
import pandas as pd
from index_analyze.rolling_investment import run

data = run(Path("../data/monthly"))

# %%
import yfinance as yf
import pandas as pd

data = yf.download("^OMX", start="2023-01-01", end="2024-01-20", interval="1mo")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
print(data.rename(columns={"Close":"OMX"}).to_csv(date_format="%Y-%m", columns=["OMX"]))
# Out:
# Date,OMX
# 2023-01,2198.5400390625
# 2023-02,2226.75
# 2023-03,2223.75
# 2023-04,2270.580078125
# 2023-05,2234.9599609375
# 2023-06,2309.89990234375
# 2023-07,2250.919921875
# 2023-08,2184.739990234375
# 2023-09,2155.489990234375
# 2023-10,2075.7900390625
# 2023-11,2232.4599609375
# 2023-12,2398.169921875
# 2024-01,2370.1298828125

# %%
from index_analyze.lib.read_data import load_directory
from index_analyze.buy_every import build_analyze_matrix

directory = Path("../data/monthly")
result = pd.DataFrame()
raw_data = load_directory(directory)

years = 5

data = build_analyze_matrix(raw_data, years)
data
# Out:
#             MSCI China  MSCI EMU  Nordic Countries  \
# Date
# 1974-12-01         NaN       NaN          1.178654
# 1975-01-01         NaN       NaN          1.289902
# 1975-02-01         NaN       NaN          1.381078
# 1975-03-01         NaN       NaN          1.325449
# 1975-04-01         NaN       NaN          1.375387
# ...                ...       ...               ...
# 2023-09-01    0.791443  1.127789          1.111364
# 2023-10-01    0.761327  1.086695          1.072620
# 2023-11-01    0.782124  1.204006          1.174734
# 2023-12-01    0.766215  1.250174          1.246898
# 2024-01-01         NaN       NaN               NaN
#
#             MSCI AC Asia Pacific ex-Japan  Brazil Bovespa  Silver  \
# Date
# 1974-12-01                            NaN             NaN     NaN
# 1975-01-01                            NaN             NaN     NaN
# 1975-02-01                            NaN             NaN     NaN
# 1975-03-01                            NaN             NaN     NaN
# ...

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

columns = [
    "MSCI World Information Technology",
    "Nasdaq 100",
    "MSCI USA",
    "Nasdaq Composite",
    "S&P 500",
    "Dow Jones Industrial Average",
    # "MSCI World Small Cap",
    # "MSCI Europe Value",
    "MSCI World",
    # "MSCI ACWI",
    # "Vanguard Small Cap Index Adm",
    # "AEX",
    # "MSCI AC Asia Pacific ex-Japan",
    "OMX",
    # "MSCI Japan",
    "MSCI EMU",
    # "MSCI China",
]

plt.rcParams['figure.figsize'] = [15, 6]  # Set default figure size
data[columns]['2003-01-01':].plot()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))  # Place legend outside
plt.tight_layout()
plt.show()
