# %%
from pathlib import Path
import pandas as pd
from index_analyze.rolling_investment import run

data = run(Path("../data/monthly"))
# Out:
#                                          mean     median       min  \
# Bitcoin                            105.775718  42.527184  1.190778
# Nasdaq-100                           2.325046   2.256932  1.228606
# MSCI World Information Technology    2.405832   2.198677  1.520254
# MSCI USA                             1.840499   1.875115  0.719759
# Dow Jones Industrial Average         1.743088   1.719115  0.754316
# S&P 500                              1.709044   1.686159  0.709459
# MSCI World                           1.678668   1.603822  0.746365
# MSCI World Small Cap                 1.636883   1.517030  0.781527
# MSCI Europe Value                    1.806936   1.511222  0.551558
# AEX                                  1.534097   1.478827  1.071121
# MSCI ACWI                            1.505857   1.463493  0.756902
# MSCI ACWI IMI                        1.462927   1.411479  0.769885
# MSCI EMU                             1.518913   1.408369  0.545448
# ...
